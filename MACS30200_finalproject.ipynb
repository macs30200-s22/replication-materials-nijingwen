# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import imblearn
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
# %matplotlib inline
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib import pylab
pylab.rcParams["figure.figsize"] = (5.0, 4.0)
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_classification
from imblearn.under_sampling import NearMiss
from matplotlib import pyplot
from sklearn import preprocessing
from numpy import where
import functools
from functools import reduce
import operator
import seaborn as sns

# %%
import statsmodels.api as sm
sm.__version__
# Out:
# '0.12.2'

# %%
path='MACS30200_data.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Year   Province      GDP        CPI   Population  Graduations_College  \
# 0  2008   Shanghai  14536.9  105.78257  2140.643464               5.6190
# 1  2008     Yunnan   6016.6  105.69938  4543.000000               4.3474
# 2  2008  Neimenggu   6242.4  105.74208  2444.330000               4.6597
# 3  2008    Beijing  11813.1  105.06181  1771.000000               4.3856
# 4  2008      Jilin   4834.7  105.11340  2734.210000               3.9125
#
#    Graduations_University  Total_retail_sales  First_industry  \
# 0                  7.6945              4577.2           109.4
# 1                  4.4059              1764.7          1001.9
# 2                  3.2567              2463.0           902.9
# 3                 11.6409              4645.5           111.4
# 4                  8.9515              2549.2           863.6
#
#    Second_industry  Third_industry  Natural_Population_growth_rate  \
# 0           6215.5          8212.1                            2.72
# 1           2476.1          2538.6                            6.32
# 2           2555.1          2784.4                            4.27
# 3           2526.7          9175.1                            3.42
# 4           1788.0          2183.2                            1.61
#
#    unemployment_rate
# 0               4.20
# 1               4.21
# 2               4.10
# 3               1.82
# 4               3.98

# %%
df.isna().sum()
# Out:
# Year                              0
# Province                          0
# GDP                               0
# CPI                               0
# Population                        0
# Graduations_College               0
# Graduations_University            0
# Total_retail_sales                0
# First_industry                    0
# Second_industry                   0
# Third_industry                    0
# Natural_Population_growth_rate    0
# unemployment_rate                 0
# dtype: int64

# %%
plt.figure(figsize = (16,5))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
df_select = df[[ "GDP", "CPI", "unemployment_rate", "Population", "Graduations_College", "Graduations_University", "First_industry"]]

# %%
df_selecty = df[[ "unemployment_rate"]]

# %%
df_selectx = df[["GDP", "CPI", "Population", "Graduations_College", "Graduations_University", "First_industry"]]
df_selectx
# Out:
#           GDP        CPI   Population  Graduations_College  \
# 0    14536.90  105.78257  2140.643464               5.6190
# 1     6016.60  105.69938  4543.000000               4.3474
# 2     6242.40  105.74208  2444.330000               4.6597
# 3    11813.10  105.06181  1771.000000               4.3856
# 4     4834.70  105.11340  2734.210000               3.9125
# ..        ...        ...          ...                  ...
# 367  24855.26  102.40000  4277.000000               8.8580
# 368  23605.77  102.70000  3188.000000              10.1469
# 369  25793.17  102.90000  3944.000000              12.7426
# 370   2941.07  102.50000   590.000000               1.0351
# 371  13544.43  102.80000  3255.000000               6.5921
#
#      Graduations_University  First_industry
# 0                    7.6945          109.40
# 1                    4.4059         1001.90
# 2                    3.2567          902.90
# 3                   11.6409          111.40
# 4                    8.9515          863.60
# ..                      ...             ...
# 367                 17.5373         2177.97
# 368                 11.6503         1551.59
# 369                 17.2024         1991.11
# 370                  0.9662          301.90
# 371                 12.9204         3183.20
#
# [372 rows x 6 columns]

# %%
# data scaling
scaler = preprocessing.StandardScaler().fit(df_selectx)

# %%
df_scaledx = scaler.transform(df_selectx)
df_scaledx
# Out:
# array([[-0.31149242,  1.7198801 , -0.80021335, -0.68041739, -0.50960365,
#         -1.25856826],
#        [-0.77480389,  1.67384848,  0.04787044, -0.84173798, -0.97657369,
#         -0.53932741],
#        [-0.76252548,  1.69747572, -0.69300544, -0.80211827, -1.13975619,
#         -0.61910875],
#        ...,
#        [ 0.30059389,  0.12486416, -0.16358951,  0.22331285,  0.8404859 ,
#          0.25784933],
#        [-0.94204311, -0.09646832, -1.34762402, -1.26195046, -1.46499942,
#         -1.10343788],
#        [-0.36546032,  0.06953104, -0.4068214 , -0.55696578,  0.23245642,
#          1.2185214 ]])

# %%
df_selectx["GDP"] = df_scaledx[:,0]
df_selectx["CPI"] = df_scaledx[:,1]
df_selectx["Population"] = df_scaledx[:,2]
df_selectx["Graduations_College"] = df_scaledx[:,3]
df_selectx["Graduations_University"] = df_scaledx[:,4]
df_selectx["First_industry"] = df_scaledx[:,5]
# Out:
# <ipython-input-89-cf136ecdeb38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["GDP"] = df_scaledx[:,0]
# <ipython-input-89-cf136ecdeb38>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["CPI"] = df_scaledx[:,1]
# <ipython-input-89-cf136ecdeb38>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["Population"] = df_scaledx[:,2]
# <ipython-input-89-cf136ecdeb38>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["Graduations_College"] = df_scaledx[:,3]
# <ipython-input-89-cf136ecdeb38>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["Graduations_University"] = df_scaledx[:,4]
# <ipython-input-89-cf136ecdeb38>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selectx["First_industry"] = df_scaledx[:,5]

# %%
df_selectx
# Out:
#           GDP       CPI  Population  Graduations_College  \
# 0   -0.311492  1.719880   -0.800213            -0.680417
# 1   -0.774804  1.673848    0.047870            -0.841738
# 2   -0.762525  1.697476   -0.693005            -0.802118
# 3   -0.459605  1.321061   -0.930705            -0.836892
# 4   -0.839072  1.349607   -0.590672            -0.896911
# ..        ...       ...         ...                  ...
# 367  0.249593 -0.151801   -0.046033            -0.269504
# 368  0.181649  0.014198   -0.430474            -0.105989
# 369  0.300594  0.124864   -0.163590             0.223313
# 370 -0.942043 -0.096468   -1.347624            -1.261950
# 371 -0.365460  0.069531   -0.406821            -0.556966
#
#      Graduations_University  First_industry
# 0                 -0.509604       -1.258568
# 1                 -0.976574       -0.539327
# 2                 -1.139756       -0.619109
# 3                  0.050772       -1.256957
# 4                 -0.331114       -0.650780
# ..                      ...             ...
# 367                0.888041        0.408435
# 368                0.052107       -0.096348
# 369                0.840486        0.257849
# 370               -1.464999       -1.103438
# 371                0.232456        1.218521
#
# [372 rows x 6 columns]

# %%
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(df_selectx, df_selecty, test_size = 0.2, random_state = 42)

# %%
Linear_reg = LinearRegression()
model = Linear_reg.fit(X_train_reg, y_train_reg)

print(Linear_reg.score(X_train_reg, y_train_reg))
print(Linear_reg.score(X_test_reg, y_test_reg))
# Out:
# 0.1578508936173859
# 0.16252260713918965

# %%
coef_order = model.coef_[0].argsort()[::-1] #get the order of indices of reg.coef_
x, y = [], []
for i in zip(model.coef_[0][coef_order], model.feature_names_in_[coef_order]):
    y.append(i[0])
    x.append(i[1])
    print('{:.3f}'.format(i[0]), i[1])
# Out:
# 0.259 Population
# 0.151 First_industry
# 0.073 Graduations_University
# 0.012 CPI
# -0.078 Graduations_College
# -0.452 GDP

# %%
plt.figure(figsize = (16,5))
plt.bar(x, y)
plt.title("Feature Importance")
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
#predict employment based on data in 2020
path2020='2020data.csv'
df_2020 = pd.read_csv(path2020)

# %%
df_2020
# Out:
#         Province        GDP    CPI    Population  Graduations_College  \
# 0       Shanghai   38963.30  101.7   2488.223752               4.6321
# 1         Yunnan   24555.72  103.6   4722.224382              13.5539
# 2      Neimenggu   17258.04  101.9   2402.800479               6.7816
# 3        Beijing   35943.25  101.7   2189.000000               2.7969
# 4          Jilin   12255.98  102.3   2399.229814               6.3259
# 5        Sichuan   48501.64  103.2   8370.698567              23.6548
# 6        Tianjin   14007.99  102.0   1386.841080               6.0558
# 7        Ningxia    3956.34  101.5    720.931970               1.4667
# 8          Anhui   38061.51  102.7   6104.761696              16.2286
# 9       Shandong   72798.17  102.8  10164.510620              34.5711
# 10        Shanxi   17835.58  102.9   3490.393920               8.8197
# 11     Guangdong  111151.63  102.6  12623.613350              30.4741
# 12       Guangxi   22120.87  102.8   5018.718158              16.6447
# 13      Xinjiang   13800.74  101.5   2590.488284               5.5960
# 14       Jiangsu  102807.68  102.5   8477.263140              25.7281
# 15       Jiangxi   25781.95  102.6   4519.446597              17.6276
# 16         Hebei   36013.84  102.1   7463.836988              21.3387
# 17         Henan   54259.43  102.8   9941.169646              38.1167
# 18      Zhejiang   64689.06  102.3   6468.298560              14.6652
# 19        Hainan    5566.24  102.3   1011.664861               2.6704
# 20         Hubei   43004.49  102.7   5744.826840              19.9738
# 21         Hunan   41542.57  102.3   6645.303680              21.8483
# 22         Gansu    8979.67  102.0   2500.508400               6.9402
# 23        Fujian   43608.55  102.2   4161.436885              10.2301
# 24        Xizang    1902.74  102.2    365.578698               0.3221
# 25       Guizhou   17860.41  102.6   3857.860563              12.6609
# 26      Liaoning   25011.38  102.4   4255.485989               9.3463
# 27     Chongqing   25041.43  102.3   3208.911207              10.7486
# 28       Shaanxi   26014.14  102.5   3954.689775              12.1989
# 29       Qinghai    3009.81  102.6    592.786972               1.0980
# 30  Heilongjiang   13633.43  102.3   3170.910613               6.6530
#
#     Graduations_University  First_industry  Confirmed    Death  Recovery  \
# 0                  10.2253          107.68     294755     2179    268043
# 1                  13.0349         3611.76      68144      659     62761
# 2                   6.8243         2028.82      80055      317     72522
# 3                  13.0796          108.28     269663     2920    242242
# 4                  12.4354         1553.04      48129      585     45235
# 5                  23.9261         5556.86     223612     1019    206211
# 6                   8.9243          210.34      75044     1018     69414
# 7                   2.0845          338.08      25753        0     24777
# 8                  17.1295         3184.95     342035     2033    323551
# 9                  28.6303         5364.35     276474     2297    258692
# 10                 13.4483         1166.60      66578        0     62628
# 11                 29.4258         4732.74     589457     2639    551739
# 12                 13.6919         3645.92      88775      678     82713
# 13                  4.6176         1981.30     169995      987    152970
# 14                 29.2853         4537.58     227332        0    215898
# 15                 13.7740         2243.79     322702      340    307144
# 16                 20.3191         3880.35     122644     2028    112015
# 17                 31.1402         5354.02     442247     7390    414934
# 18                 16.6251         2166.26     440771      329    416417
# 19                  2.8903         1135.98      58746     2015     53924
# 20                 22.7013         4133.20   23087143  1420242  20245969
# 21                 18.4929         4240.73     352988     1345    335383
# 22                  7.3698         1188.09      53527      682     50471
# 23                 13.0754         2730.81     134247      330    123547
# 24                  0.5852          150.32        351        0       337
# 25                  9.1958         2539.93      50461      673     47394
# 26                 17.3908         2284.78      73918      637     66908
# 27                 11.7408         1803.54     201754     2034    188724
# 28                 17.8483         2267.73     123995      942    113530
# 29                  0.9896          337.99       6286        0      6044
# 30                 13.3301         3445.06     294914     4418    270825
#
#     unemployment_rate  gap_value
# 0                3.67   0.371442
# 1                3.92  -0.493664
# 2                3.80   0.008819
# 3                2.56   1.011339
# 4                3.42   0.851248
# 5                3.63  -1.456136
# 6                3.62  -0.096973
# 7                3.92   0.457216
# 8                2.83   1.591420
# 9                3.10  -1.761444
# 10               3.11  -1.129816
# 11               2.53  -1.633481
# 12               2.77  -1.746585
# 13               2.39  -1.345809
# 14               3.20  -0.802080
# 15               3.15  -1.054820
# 16               3.46  -1.398307
# 17               3.24  -2.202944
# 18               2.79  -0.862052
# 19               2.78  -0.819415
# 20               3.35  -1.401460
# 21               2.74  -1.815199
# 22               3.27  -0.669662
# 23               3.82   0.006982
# 24               2.90  -0.464834
# 25               3.75  -0.340985
# 26               4.61   0.061821
# 27               4.49   0.522536
# 28               3.63  -0.869856
# 29               2.13  -1.275798
# 30               3.37  -1.230702

# %%
#scale
df_select2020 = df_2020[["GDP", "CPI", "Population", "Graduations_College", "Graduations_University", "First_industry"]]

# %%
scaler_2020 = preprocessing.StandardScaler().fit(df_select2020)

# %%
df_scaled2020 = scaler.transform(df_select2020)
#df_scaled2020

# %%
df_select2020["GDP"] = df_scaled2020[:,0]
df_select2020["CPI"] = df_scaled2020[:,1]
df_select2020["Population"] = df_scaled2020[:,2]
df_select2020["Graduations_College"] = df_scaled2020[:,3]
df_select2020["First_industry"] = df_scaled2020[:,5]
df_select2020
# Out:
# <ipython-input-100-19920ce08fdf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select2020["GDP"] = df_scaled2020[:,0]
# <ipython-input-100-19920ce08fdf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select2020["CPI"] = df_scaled2020[:,1]
# <ipython-input-100-19920ce08fdf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select2020["Population"] = df_scaled2020[:,2]
# <ipython-input-100-19920ce08fdf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select2020["Graduations_College"] = df_scaled2020[:,3]
# <ipython-input-100-19920ce08fdf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select2020["First_industry"] = df_scaled2020[:,5]
#          GDP       CPI  Population  Graduations_College  \
# 0   1.016751 -0.539133   -0.677510            -0.805620
# 1   0.233305  0.512196    0.111141             0.326238
# 2  -0.163524 -0.428467   -0.707666            -0.532925
# 3   0.852528 -0.539133   -0.783142            -1.038441
# 4  -0.435523 -0.207135   -0.708927            -0.590737
# 5   1.535421  0.290864    1.399131             1.607681
# 6  -0.340253 -0.373134   -1.066322            -0.625003
# 7  -0.886835 -0.649800   -1.301402            -1.207196
# 8   0.967714  0.014198    0.599206             0.665562
# 9   2.856602  0.069531    2.032385             2.992569
# 10 -0.132119  0.124864   -0.323722            -0.274363
# 11  4.942162 -0.041135    2.900502             2.472806
# 12  0.100904  0.069531    0.215809             0.718350
# 13 -0.351523 -0.649800   -0.641408            -0.683335
# 14  4.488440 -0.096468    1.436750             1.870709
# 15  0.299984 -0.041135    0.039556             0.843045
# 16  0.856367 -0.317801    1.078989             1.313851
# 17  1.848514  0.069531    1.953541             3.442379
# 18  2.415650 -0.207135    0.727542             0.467222
# 19 -0.799293 -0.207135   -1.198767            -1.054489
# 20  1.236500  0.014198    0.472141             1.140694
# 21  1.157005 -0.207135    0.790029             1.378501
# 22 -0.613680 -0.373134   -0.673173            -0.512804
# 23  1.269347 -0.262468   -0.086830            -0.095434
# 24 -0.998505 -0.262468   -1.426850            -1.352405
# 25 -0.130769 -0.041135   -0.193999             0.212948
# 26  0.258082 -0.151801   -0.053628            -0.207556
# 27  0.259716 -0.207135   -0.423092            -0.029654
# 28  0.312610 -0.096468   -0.159816             0.154337
# 29 -0.938305 -0.041135   -1.346640            -1.253971
# 30 -0.360621 -0.207135   -0.436507            -0.549240
#
#     Graduations_University  First_industry
# 0                  10.2253       -1.259954
# 1                  13.0349        1.563886
# 2                   6.8243        0.288239
# 3                  13.0796       -1.259471
# 4                  12.4354       -0.095179
# 5                  23.9261        3.131388
# 6                   8.9243       -1.177224
# 7                   2.0845       -1.074281
# 8                  17.1295        1.219932
# 9                  28.6303        2.976249
# 10                 13.4483       -0.406600
# 11                 29.4258        2.467252
# 12                 13.6919        1.591415
# 13                  4.6176        0.249944
# 14                 29.2853        2.309978
# 15                 13.7740        0.461477
# 16                 20.3191        1.780335
# 17                 31.1402        2.967925
# 18                 16.6251        0.398998
# 19                  2.8903       -0.431276
# 20                 22.7013        1.984100
# 21                 18.4929        2.070755
# 22                  7.3698       -0.389282
# 23                 13.0754        0.853953
# 24                  0.5852       -1.225592
# 25                  9.1958        0.700128
# 26                 17.3908        0.494510
# 27                 11.7408        0.106692
# 28                 17.8483        0.480770
# 29                  0.9896       -1.074354
# 30                 13.3301        1.429547

# %%
predict = model.predict(df_select2020)
#predict

# %%
df_employ =  df_2020[["Province", "unemployment_rate"]]
df_employ
# Out:
#         Province  unemployment_rate
# 0       Shanghai               3.67
# 1         Yunnan               3.92
# 2      Neimenggu               3.80
# 3        Beijing               2.56
# 4          Jilin               3.42
# 5        Sichuan               3.63
# 6        Tianjin               3.62
# 7        Ningxia               3.92
# 8          Anhui               2.83
# 9       Shandong               3.10
# 10        Shanxi               3.11
# 11     Guangdong               2.53
# 12       Guangxi               2.77
# 13      Xinjiang               2.39
# 14       Jiangsu               3.20
# 15       Jiangxi               3.15
# 16         Hebei               3.46
# 17         Henan               3.24
# 18      Zhejiang               2.79
# 19        Hainan               2.78
# 20         Hubei               3.35
# 21         Hunan               2.74
# 22         Gansu               3.27
# 23        Fujian               3.82
# 24        Xizang               2.90
# 25       Guizhou               3.75
# 26      Liaoning               4.61
# 27     Chongqing               4.49
# 28       Shaanxi               3.63
# 29       Qinghai               2.13
# 30  Heilongjiang               3.37

# %%
keys = df_employ['Province'].values.tolist()
#keys

# %%
employ_num = df_employ.values[:,1:]
#employ_num

# %%
gap = employ_num - predict
#gap

# %%
gap_values = gap.tolist()
#gap_values

# %%
gap_List_flat = functools.reduce(operator.iconcat, gap_values, [])
#gap_List_flat

# %%
dictionary = dict(zip(keys, gap_List_flat))
#print(dictionary)

# %%
df_gap = pd.DataFrame(dictionary.items(), columns=['Province', 'gap_value'])
df_gap
# Out:
#         Province  gap_value
# 0       Shanghai   0.371442
# 1         Yunnan  -0.493664
# 2      Neimenggu   0.008819
# 3        Beijing  -1.011339
# 4          Jilin  -0.851248
# 5        Sichuan  -1.456136
# 6        Tianjin  -0.096973
# 7        Ningxia   0.457216
# 8          Anhui  -1.591420
# 9       Shandong  -1.761444
# 10        Shanxi  -1.129816
# 11     Guangdong  -1.633481
# 12       Guangxi  -1.746585
# 13      Xinjiang  -1.345809
# 14       Jiangsu  -0.802080
# 15       Jiangxi  -1.054820
# 16         Hebei  -1.398307
# 17         Henan  -2.202944
# 18      Zhejiang  -0.862052
# 19        Hainan  -0.819415
# 20         Hubei  -1.401460
# 21         Hunan  -1.815199
# 22         Gansu  -0.669662
# 23        Fujian   0.006982
# 24        Xizang  -0.464834
# 25       Guizhou  -0.340985
# 26      Liaoning   0.061821
# 27     Chongqing   0.522536
# 28       Shaanxi  -0.869856
# 29       Qinghai  -1.275798
# 30  Heilongjiang  -1.230702

# %%
df_gap.to_csv('gap.csv')

# %%
x = df_gap["Province"]
y = df_gap["gap_value"]

# %%
plt.figure(figsize = (40,20))
plt.bar(x, y)
plt.title("gap between predicted umemployment rate and true unemployment rate in 2020")
# Out:
# Text(0.5, 1.0, 'gap between predicted umemployment rate and true unemployment rate in 2020')

# %%
#14 province: Henan
abs(df_gap["gap_value"]).max()
# Out:
# 2.202944013542778

# %%
#24 province: Fujian
abs(df_gap["gap_value"]).min()
# Out:
# 0.006982261585973593

# %%
df_2020.head()
# Out:
#     Province       GDP    CPI   Population  Graduations_College  \
# 0   Shanghai  38963.30  101.7  2488.223752               4.6321
# 1     Yunnan  24555.72  103.6  4722.224382              13.5539
# 2  Neimenggu  17258.04  101.9  2402.800479               6.7816
# 3    Beijing  35943.25  101.7  2189.000000               2.7969
# 4      Jilin  12255.98  102.3  2399.229814               6.3259
#
#    Graduations_University  First_industry  Confirmed  Death  Recovery  \
# 0                 10.2253          107.68     294755   2179    268043
# 1                 13.0349         3611.76      68144    659     62761
# 2                  6.8243         2028.82      80055    317     72522
# 3                 13.0796          108.28     269663   2920    242242
# 4                 12.4354         1553.04      48129    585     45235
#
#    unemployment_rate  gap_value
# 0               3.67   0.371442
# 1               3.92  -0.493664
# 2               3.80   0.008819
# 3               2.56   1.011339
# 4               3.42   0.851248

# %%
plt.figure(figsize = (16,5))
dataplot = sns.heatmap(df_2020.corr(), cmap="YlGnBu", annot=True)

# %%
#scale
df_2020_scale = df_2020.drop(columns = "Province")
scaler = preprocessing.StandardScaler().fit(df_2020_scale)

# %%
df_covid = scaler.transform(df_2020_scale)
#df_covid

# %%
df_2020["GDP"] = df_covid[:,0]
df_2020["CPI"] = df_covid[:,1]
df_2020["Population"] = df_covid[:,2]
df_2020["Graduations_College"] = df_covid[:,3]
df_2020["Graduations_University"] = df_covid[:,4]
df_2020["First_industry"] = df_covid[:,5]
df_2020["Confirmed"] = df_covid[:,5]
df_2020["Death"] = df_covid[:,6]
df_2020["Recovery"] = df_covid[:,7]
df_2020["gap_value"] = df_covid[:,8]
df_2020
# Out:
#         Province       GDP       CPI  Population  Graduations_College  \
# 0       Shanghai  0.243464 -1.486411   -0.685872            -0.881076
# 1         Yunnan -0.305934  2.643288    0.057730             0.034433
# 2      Neimenggu -0.584214 -1.051706   -0.714306            -0.660505
# 3        Beijing  0.128302 -1.486411   -0.785471            -1.069394
# 4          Jilin -0.774955 -0.182296   -0.715495            -0.707267
# 5        Sichuan  0.607185  1.773878    1.272149             1.070934
# 6        Tianjin -0.708146 -0.834354   -1.052475            -0.734983
# 7        Ningxia -1.091442 -1.921117   -1.274127            -1.205892
# 8          Anhui  0.209076  0.687115    0.517916             0.308896
# 9       Shandong  1.533675  0.904467    1.869231             2.191107
# 10        Shanxi -0.562191  1.121820   -0.352293            -0.451366
# 11     Guangdong  2.996191  0.469762    2.687760             1.770695
# 12       Guangxi -0.398781  0.904467    0.156420             0.351594
# 13      Xinjiang -0.716049 -1.921117   -0.651833            -0.782165
# 14       Jiangsu  2.678014  0.252409    1.307619             1.283685
# 15       Jiangxi -0.259175  0.469762   -0.009766             0.452454
# 16         Hebei  0.130993 -0.617001    0.970294             0.833268
# 17         Henan  0.826745  0.904467    1.794891             2.554938
# 18      Zhejiang  1.224453 -0.182296    0.638922             0.148468
# 19        Hainan -1.030052 -0.182296   -1.177355            -1.082375
# 20         Hubei  0.397565  0.687115    0.398110             0.693209
# 21         Hunan  0.341818 -0.182296    0.697839             0.885560
# 22         Gansu -0.899889 -0.834354   -0.681783            -0.644231
# 23        Fujian  0.420599 -0.399648   -0.128932            -0.306638
# 24        Xizang -1.169751 -0.399648   -1.392409            -1.323345
# 25       Guizhou -0.561244  0.469762   -0.229980            -0.057202
# 26      Liaoning -0.288559  0.035057   -0.097627            -0.397329
# 27     Chongqing -0.287413 -0.182296   -0.445987            -0.253433
# 28       Shaanxi -0.250321  0.252409   -0.197749            -0.104610
# 29       Qinghai -1.127535  0.469762   -1.316781            -1.243726
# 30  Heilongjiang -0.722429 -0.182296   -0.458636            -0.673702
#
#     Graduations_University  First_industry  Confirmed     Death  Recovery  \
# 0                -0.495700       -1.451196  -1.451196 -0.155148 -0.179263
# 1                -0.156406        0.659293   0.659293 -0.211113 -0.185326
# 2                -0.906412       -0.294104  -0.294104 -0.208171 -0.186691
# 3                -0.151008       -1.450834  -1.450834 -0.161345 -0.176308
# 4                -0.228803       -0.580663  -0.580663 -0.216056 -0.185622
# 5                 1.158839        1.830816   1.830816 -0.172718 -0.183890
# 6                -0.652811       -1.389364  -1.389364 -0.209409 -0.183894
# 7                -1.478801       -1.312427  -1.312427 -0.221582 -0.187955
# 8                 0.338067        0.402227   0.402227 -0.143472 -0.179846
# 9                 1.726929        1.714868   1.714868 -0.159663 -0.178793
# 10               -0.106483       -0.813414  -0.813414 -0.211499 -0.187955
# 11                1.822996        1.334453   1.334453 -0.082368 -0.177429
# 12               -0.077065        0.679867   0.679867 -0.206018 -0.185251
# 13               -1.172898       -0.322725  -0.322725 -0.185959 -0.184018
# 14                1.806028        1.216909   1.216909 -0.171799 -0.187955
# 15               -0.067151       -0.164628  -0.164628 -0.148247 -0.186599
# 16                0.723250        0.821063   0.821063 -0.197653 -0.179866
# 17                2.030030        1.708646   1.708646 -0.118724 -0.158478
# 18                0.277154       -0.211324  -0.211324 -0.119088 -0.186643
# 19               -1.381491       -0.831856  -0.831856 -0.213434 -0.179918
# 20                1.010930        0.973353   0.973353  5.473698  5.477127
# 21                0.502714        1.038118   1.038118 -0.140767 -0.182590
# 22               -0.840536       -0.800471  -0.800471 -0.214722 -0.185235
# 23               -0.151515        0.128701   0.128701 -0.194788 -0.186639
# 24               -1.659860       -1.425514  -1.425514 -0.227855 -0.187955
# 25               -0.620024        0.013735   0.013735 -0.215480 -0.185271
# 26                0.369622       -0.139940  -0.139940 -0.209687 -0.185414
# 27               -0.312685       -0.429788  -0.429788 -0.178116 -0.179842
# 28                0.424871       -0.150209  -0.150209 -0.197320 -0.184198
# 29               -1.611024       -1.312481  -1.312481 -0.226389 -0.187955
# 30               -0.120757        0.558890   0.558890 -0.155109 -0.170332
#
#     unemployment_rate  gap_value
# 0                3.67  -0.155259
# 1                3.92  -0.213093
# 2                3.80  -0.210343
# 3                2.56  -0.162527
# 4                3.42  -0.218031
# 5                3.63  -0.172679
# 6                3.62  -0.211219
# 7                3.92  -0.223794
# 8                2.83  -0.139620
# 9                3.10  -0.157893
# 10               3.11  -0.213131
# 11               2.53  -0.075332
# 12               2.77  -0.207472
# 13               2.39  -0.187678
# 14               3.20  -0.169949
# 15               3.15  -0.144242
# 16               3.46  -0.199217
# 17               3.24  -0.113875
# 18               2.79  -0.113457
# 19               2.78  -0.215583
# 20               3.35   5.473173
# 21               2.74  -0.136287
# 22               3.27  -0.216556
# 23               3.82  -0.195968
# 24               2.90  -0.230680
# 25               3.75  -0.217423
# 26               4.61  -0.211925
# 27               4.49  -0.177605
# 28               3.63  -0.198790
# 29               2.13  -0.229072
# 30               3.37  -0.154475

# %%
#statistics
import statsmodels.api as sm
x = df_2020[['Confirmed', "Death", "Recovery"]]
y = df_2020[['gap_value']]
covid_data = sm.add_constant(x)
model_covid = sm.OLS(y, covid_data).fit()
summary_covid = model_covid.summary()
print(summary_covid)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              gap_value   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.371e+07
# Date:                Mon, 25 Apr 2022   Prob (F-statistic):           1.46e-83
# Time:                        13:05:44   Log-Likelihood:                 176.67
# No. Observations:                  31   AIC:                            -345.3
# Df Residuals:                      27   BIC:                            -339.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const               0      0.000          0      1.000      -0.000       0.000
# Confirmed      0.0003      0.000      1.670      0.107   -6.97e-05       0.001
# Death          1.0744      0.005    196.630      0.000       1.063       1.086
# Recovery      -0.0745      0.005    -13.673      0.000      -0.086      -0.063
# ==============================================================================
# Omnibus:                        1.901   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.697
# Skew:                          -0.536   Prob(JB):                        0.428
# Kurtosis:                       2.596   Cond. No.                         71.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_reg_covid = df_2020[["GDP", "CPI", "Population", "Graduations_College", "Graduations_University", "First_industry", "Confirmed", "Death", "Recovery"]]
y_reg_covid = df_2020[["unemployment_rate"]]

# %%
Linear_reg = LinearRegression()
model_covid = Linear_reg.fit(X_reg_covid, y_reg_covid)


print(Linear_reg.score(X_reg_covid, y_reg_covid))
# Out:
# 0.2507085670345707

# %%
# relation between GDP and gap_Emloyment
linear_GDP = sns.regplot(x="GDP", y="gap_value", data=df_2020)
linear_GDP.set_title("GDP and gap_Employment")
# Out:
# Text(0.5, 1.0, 'GDP and gap_Employment')

# %%
# relation between CPI and gap_Employment
linear_CPI = sns.regplot(x="CPI", y="gap_value", data=df_2020)
linear_CPI.set_title("CPI and gap_Employment")
# Out:
# Text(0.5, 1.0, 'CPI and gap_Employment')

# %%
# relation between Population and gap_Employment
linear_Population = sns.regplot(x="Population", y="gap_value", data=df_2020)
linear_Population.set_title("Population and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Population and gap_Employment')

# %%
# relation between Graduations_College and gap_Employment
linear_College = sns.regplot(x="Graduations_College", y="gap_value", data=df_2020)
linear_College.set_title("Graduations_College and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Graduations_College and gap_Employment')

# %%
# relation between Graduations_University and gap_Employment
linear_University = sns.regplot(x="Graduations_University", y="gap_value", data=df_2020)
linear_University.set_title("Graduations_University and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Graduations_University and gap_Employment')

# %%
# relation between First_industry and gap_Employment
linear_First = sns.regplot(x="First_industry", y="gap_value", data=df_2020)
linear_First.set_title("First_industry and gap_Employment")
# Out:
# Text(0.5, 1.0, 'First_industry and gap_Employment')

# %%
# relation between Confirmed and gap_Employment
linear_Confirmed = sns.regplot(x="Confirmed", y="gap_value", data=df_2020)
linear_Confirmed.set_title("Confirmed and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Confirmed and gap_Employment')

# %%
# relation between Death and gap_Employment
linear_Death = sns.regplot(x="Death", y="gap_value", data=df_2020)
linear_Death.set_title("Death and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Death and gap_Employment')

# %%
# relation between Death and gap_Employment
linear_Recovery = sns.regplot(x="Recovery", y="gap_value", data=df_2020)
linear_Recovery.set_title("Recovery and gap_Employment")
# Out:
# Text(0.5, 1.0, 'Recovery and gap_Employment')

# %%
coef_order1 = model_covid.coef_[0].argsort()[::-1] #get the order of indices of reg.coef_
x, y = [], []
for i in zip(model_covid.coef_[0][coef_order], model_covid.feature_names_in_[coef_order1]):
    y.append(i[0])
    x.append(i[1])
    print('{:.3f}'.format(i[0]), i[1])
# Out:
# -0.287 Recovery
# 0.066 Graduations_University
# 0.632 First_industry
# -0.053 Confirmed
# -0.206 CPI
# -0.097 GDP

# %%
plt.figure(figsize = (40,20))
plt.bar(x, y)
plt.title("Feature importance of unemployment rate in 2020")
# Out:
# Text(0.5, 1.0, 'Feature importance of unemployment rate in 2020')
